# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Bank_Stock_Price_10Y.csv')

# %%
df.head()
# Out:
#          Date    Open    High     Low   Close    Adj Close     Volume
# 0  2014-02-03  1980.0  2000.0  1965.0  1965.0  1691.382568   55407000
# 1  2014-02-04  1970.0  1980.0  1940.0  1970.0  1695.686035   83683500
# 2  2014-02-05  1980.0  1990.0  1965.0  1990.0  1712.901367   42715000
# 3  2014-02-06  1975.0  2030.0  1970.0  2030.0  1747.331299   63581000
# 4  2014-02-07  2050.0  2060.0  2035.0  2050.0  1764.546753  104825500

# %%
df.tail()
# Out:
#             Date    Open    High     Low   Close  Adj Close    Volume
# 2478  2024-01-24  9600.0  9600.0  9475.0  9525.0     9525.0  84906000
# 2479  2024-01-25  9450.0  9575.0  9450.0  9500.0     9500.0  63212700
# 2480  2024-01-26  9400.0  9450.0  9300.0  9350.0     9350.0  78977300
# 2481  2024-01-29  9400.0  9550.0  9375.0  9550.0     9550.0  73452800
# 2482  2024-01-30  9500.0  9650.0  9475.0  9650.0     9650.0  73136400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483 entries, 0 to 2482
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2483 non-null   object
#  1   Open       2483 non-null   float64
#  2   High       2483 non-null   float64
#  3   Low        2483 non-null   float64
#  4   Close      2483 non-null   float64
#  5   Adj Close  2483 non-null   float64
#  6   Volume     2483 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 135.9+ KB

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df1=df.sample(frac=0.5)

# %%
df1.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df1=df1.drop('Date',axis=1)

# %%
df1
# Out:
#         Open    High     Low   Close    Adj Close     Volume
# 66    2190.0  2240.0  2190.0  2240.0  1941.326294   33977000
# 2317  9250.0  9250.0  9075.0  9150.0  9106.550781   79148200
# 778   3365.0  3400.0  3310.0  3310.0  2948.972900   81642500
# 2481  9400.0  9550.0  9375.0  9550.0  9550.000000   73452800
# 534   2640.0  2650.0  2620.0  2620.0  2304.116699  101318500
# ...      ...     ...     ...     ...          ...        ...
# 2436  8775.0  8875.0  8775.0  8875.0  8832.856445   40364800
# 609   2875.0  2995.0  2875.0  2975.0  2637.537109  221091000
# 135   2360.0  2365.0  2340.0  2360.0  2045.326172   58021500
# 909   4060.0  4080.0  4050.0  4070.0  3653.452881   65156500
# 2228  8325.0  8450.0  8325.0  8450.0  8245.070313   86916900
#
# [1242 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
X1=df1.drop('Adj Close',axis=1)
y1=df1.Close

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=1)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

model = DecisionTreeRegressor(random_state=1)
model.fit(X_train_scaled, y_train)
predicted_scaled = model.predict(X_test_scaled)

r2 = r2_score(y_test, predicted_scaled)
print(f'R-squared with scaled features: {r2}')
# Out:
# R-squared with scaled features: 0.9999212450394583

# %%
df2=df.sample(frac=0.5)

# %%
df2.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df2=df2.drop('Date',axis=1)

# %%
df2
# Out:
#         Open    High     Low   Close    Adj Close     Volume
# 397   2380.0  2385.0  2360.0  2370.0  2075.422852   66782000
# 1881  6520.0  6760.0  6460.0  6600.0  6296.933105  186354500
# 1042  4665.0  4665.0  4610.0  4630.0  4171.807617   45957000
# 170   2525.0  2550.0  2500.0  2525.0  2188.325684   43902500
# 1883  6600.0  6600.0  6510.0  6600.0  6296.933105  120163500
# ...      ...     ...     ...     ...          ...        ...
# 2412  8825.0  8850.0  8750.0  8750.0  8708.450195   89509700
# 1303  5460.0  5510.0  5460.0  5500.0  5009.805176   18577000
# 2396  9000.0  9025.0  8950.0  8950.0  8907.500000   73544700
# 1855  6000.0  6040.0  5980.0  6015.0  5738.795898   47297000
# 784   3525.0  3550.0  3450.0  3470.0  3091.521484   79805500
#
# [1242 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X=df2.drop('Adj Close',axis=1)
y=df2['Adj Close']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

model = DecisionTreeRegressor(random_state=1)
model.fit(X_train_scaled, y_train)
predicted_scaled = model.predict(X_test_scaled)

r2 = r2_score(y_test, predicted_scaled)
print(f'R-squared with scaled features: {r2}')
# Out:
# R-squared with scaled features: 0.9991537985679627

# %%
df3=df.sample(frac=0.5)

# %%
df3.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df3=df3.drop('Date',axis=1)

# %%
df3
# Out:
#         Open    High     Low   Close    Adj Close     Volume
# 1044  4580.0  4580.0  4580.0  4580.0  4158.189941          0
# 1804  6200.0  6225.0  6165.0  6165.0  5881.907715   68397000
# 1964  7300.0  7375.0  7275.0  7300.0  6988.161133   49763600
# 2237  8275.0  8325.0  8250.0  8300.0  8098.708008   96859500
# 1799  6105.0  6305.0  6060.0  6305.0  6015.479004  135519500
# ...      ...     ...     ...     ...          ...        ...
# 285   2960.0  2965.0  2935.0  2965.0  2579.391113   85598000
# 1347  5885.0  5885.0  5790.0  5805.0  5335.958984   78802500
# 1083  4570.0  4600.0  4420.0  4450.0  4040.162598  170845000
# 1913  6900.0  6900.0  6710.0  6760.0  6449.585938  103954500
# 511   2685.0  2710.0  2685.0  2705.0  2378.868164  115057500
#
# [1242 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X2=df3.drop('Adj Close',axis=1)
y2=df3['Adj Close']

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score


X_train, X_test, y_train, y_test = train_test_split(X2, y2, test_size=0.2, random_state=1)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

model = DecisionTreeRegressor(random_state=1)
model.fit(X_train_scaled, y_train)
predicted_scaled = model.predict(X_test_scaled)

r2 = r2_score(y_test, predicted_scaled)
print(f'R-squared with scaled features: {r2}')
# Out:
# R-squared with scaled features: 0.9987093732753547
